# %%
import tensorflow as tf
import os

# 1. Verify GPU
gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
    print(f"✅ Success! GPU Detected: {gpu_devices}")
else:
    print("❌ Error: GPU not detected. Check your drivers.")

# 2. Re-apply the CUDA Path Fix (Required for every new session)
os.environ['XLA_FLAGS'] = r"--xla_gpu_cuda_data_dir=D:\Terminal\ancondaEnviroment\driver_ai\Library"

# 3. Test the Compiler
print(f"XLA Flags set to: {os.environ['XLA_FLAGS']}")
# Out:
# ✅ Success! GPU Detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# XLA Flags set to: --xla_gpu_cuda_data_dir=D:\Terminal\ancondaEnviroment\driver_ai\Library
