# %% [markdown]
# YOLOv8 Compatible

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="f5oaGFY4GmsmmU0FebC1")
project = rf.workspace("kmitlapkdtii").project("cv-driver-distraction")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to CV-Driver-Distraction-3 in yolov8:: 100%|██████████| 4642/4642 [00:01<00:00, 3343.98it/s]

# %% [markdown]
# SSD (TensorFlow) Compatible

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="f5oaGFY4GmsmmU0FebC1")
project = rf.workspace("kmitlapkdtii").project("cv-driver-distraction")
version = project.version(3)
dataset = version.download("tfrecord")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to CV-Driver-Distraction-3 in tfrecord:: 100%|██████████| 11/11 [00:00<00:00, 87.55it/s]
